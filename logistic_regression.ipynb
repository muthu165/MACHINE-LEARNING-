# %% [markdown]
# <a href="https://colab.research.google.com/github/MUTHUKRISHNAN123/MACHINE-LEARNING-/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
ds=pd.read_csv("/content/hr.csv")
ds
# Out:
#        satisfaction  lasteval  noproject  avgmonhrs  timespend  acci  left  \
# 0              0.38      0.53          2        157          3     0     1
# 1              0.80      0.86          5        262          6     0     1
# 2              0.11      0.88          7        272          4     0     1
# 3              0.72      0.87          5        223          5     0     1
# 4              0.37      0.52          2        159          3     0     1
# ...             ...       ...        ...        ...        ...   ...   ...
# 14994          0.40      0.57          2        151          3     0     1
# 14995          0.37      0.48          2        160          3     0     1
# 14996          0.37      0.53          2        143          3     0     1
# 14997          0.11      0.96          6        280          4     0     1
# 14998          0.37      0.52          2        158          3     0     1
#
#        promotion5yrs     dept  salary
# ...

# %%
plt.scatter(ds.satisfaction,ds.salary,marker='*',color='red')

# %%
plt.scatter(ds.dept,ds.salary,marker='*',color='green')

# %%
ds.shape
# Out:
# (14999, 10)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ds[['satisfaction','lasteval','noproject',	'avgmonhrs','timespend','acci',	'left',	'promotion5yrs',	'dept']],ds.salary,train_size=0.3)

# %%
x_train
# Out:
#       satisfaction  lasteval  noproject  avgmonhrs  timespend  acci  left  \
# 2786          0.88      0.52          4        166          2     0     0
# 782           0.72      1.00          4        245          5     0     1
# 9864          0.76      0.50          3        196          3     1     0
# 6335          0.80      0.81          5        143          2     0     0
# 651           0.09      0.88          6        269          4     0     1
# ...            ...       ...        ...        ...        ...   ...   ...
# 4722          0.50      0.82          3        133          2     1     0
# 3640          0.63      0.82          5        229          2     0     0
# 4814          0.94      0.85          4        236          2     0     0
# 4981          0.80      0.96          5        124          3     0     0
# 655           0.77      1.00          4        232          5     0     1
#
#       promotion5yrs         dept
# 2786              0    technical
# ...

# %%
x_test
# Out:
#        satisfaction  lasteval  noproject  avgmonhrs  timespend  acci  left  \
# 10646          0.53      0.80          4        241          3     1     0
# 6921           0.15      0.67          5        249          5     0     0
# 13369          0.69      0.55          3        172          2     0     0
# 12073          0.09      0.87          7        295          4     0     1
# 464            0.82      0.98          5        234          5     0     1
# ...             ...       ...        ...        ...        ...   ...   ...
# 10763          0.28      0.37          3        164          4     1     0
# 1972           0.36      0.50          2        131          3     0     1
# 12428          0.37      0.45          2        126          3     0     1
# 8224           0.40      0.41          3        232          3     0     0
# 7290           0.32      0.87          2        197          2     1     0
#
#        promotion5yrs         dept
# ...

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
