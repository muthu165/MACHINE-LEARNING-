# %% [markdown]
# <a href="https://colab.research.google.com/github/MUTHUKRISHNAN123/MACHINE-LEARNING-/blob/main/LOGISTIC_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
ds=pd.read_csv("/content/hr.csv")
ds.head()
# Out:
#    satisfaction  lasteval  noproject  avgmonhrs  timespend  acci  left  \
# 0          0.38      0.53          2        157          3     0     1
# 1          0.80      0.86          5        262          6     0     1
# 2          0.11      0.88          7        272          4     0     1
# 3          0.72      0.87          5        223          5     0     1
# 4          0.37      0.52          2        159          3     0     1
#
#    promotion5yrs   dept  salary
# 0              0  sales     low
# 1              0  sales  medium
# 2              0  sales  medium
# 3              0  sales     low
# 4              0  sales     low

# %%
ds.shape
# Out:
# (14999, 10)

# %%
left=ds[ds.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retain=ds[ds.left==0]
retain.shape
# Out:
# (11428, 10)

# %%
ds.groupby('left').mean()
# Out:
#       satisfaction  lasteval  noproject   avgmonhrs  timespend      acci  \
# left
# 0         0.666810  0.715473   3.786664  199.060203   3.380032  0.175009
# 1         0.440098  0.718113   3.855503  207.419210   3.876505  0.047326
#
#       promotion5yrs
# left
# 0          0.026251
# 1          0.005321

# %% [markdown]
# impact of salary on employee retension

# %%
pd.crosstab(ds.salary,ds.left)
# Out:
# left       0     1
# salary
# high    1155    82
# low     5144  2172
# medium  5129  1317

# %% [markdown]
# dept wise employee retention rate

# %%
pd.crosstab(ds.salary,ds.dept)
# Out:
# dept     IT  RandD  accounting   hr  management  marketing  product_mng  \
# salary
# high     83     51          74   45         225         80           68
# low     609    364         358  335         180        402          451
# medium  535    372         335  359         225        376          383
#
# dept    sales  support  technical
# salary
# high      269      141        201
# low      2099     1146       1372
# medium   1772      942       1147

# %% [markdown]
# from the data independent variables are
# 1) satisfaction level 2)avg monthly hours 3)promotion ast 5 years 4)salary

# %%
sat=ds[['satisfaction','avgmonhrs','promotion5yrs','salary']]
sat.head()
# Out:
#    satisfaction  avgmonhrs  promotion5yrs  salary
# 0          0.38        157              0     low
# 1          0.80        262              0  medium
# 2          0.11        272              0  medium
# 3          0.72        223              0     low
# 4          0.37        159              0     low

# %%
sal_dum=pd.get_dummies(sat.salary,prefix="salary")
sal_dum
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
ds_dum=pd.concat([sat,sal_dum],axis='columns')
ds_dum
# Out:
#        satisfaction  avgmonhrs  promotion5yrs  salary  salary_high  \
# 0              0.38        157              0     low            0
# 1              0.80        262              0  medium            0
# 2              0.11        272              0  medium            0
# 3              0.72        223              0     low            0
# 4              0.37        159              0     low            0
# ...             ...        ...            ...     ...          ...
# 14994          0.40        151              0     low            0
# 14995          0.37        160              0     low            0
# 14996          0.37        143              0     low            0
# 14997          0.11        280              0     low            0
# 14998          0.37        158              0     low            0
#
#        salary_low  salary_medium
# 0               1              0
# 1               0              1
# 2               0              1
# ...

# %%
x=ds_dum.drop('salary',axis='columns',inplace=None)
x
# Out:
#        satisfaction  avgmonhrs  promotion5yrs  salary_high  salary_low  \
# 0              0.38        157              0            0           1
# 1              0.80        262              0            0           0
# 2              0.11        272              0            0           0
# 3              0.72        223              0            0           1
# 4              0.37        159              0            0           1
# ...             ...        ...            ...          ...         ...
# 14994          0.40        151              0            0           1
# 14995          0.37        160              0            0           1
# 14996          0.37        143              0            0           1
# 14997          0.11        280              0            0           1
# 14998          0.37        158              0            0           1
#
#        salary_medium
# 0                  0
# 1                  1
# 2                  1
# 3                  0
# ...

# %%
y=ds.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model.score(x_test,y_test)
# Out:
# 0.7806666666666666
